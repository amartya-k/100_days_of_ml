# %%
'''Linear Regression using TensorFlow'''
# Out:
# 'Linear Regression using TensorFlow'

# %%
import tensorflow as tf
import os

# %%
#Placeholder in tf
# Example 1: feed_dict with placeholder

# a is a placeholderfor a vector of 3 elements, type tf.float32
a = tf.placeholder(tf.float32, shape=[3])
b = tf.constant([5, 5, 5], tf.float32)

# use the placeholder as you would a constant
c = a + b  # short for tf.add(a, b)

writer = tf.summary.FileWriter('./graphs', tf.get_default_graph())
with tf.Session() as sess:
    # compute the value of c given the value of a is [1, 2, 3]
    print(sess.run(c, {a: [1, 2, 3]}))                 # [6. 7. 8.]
writer.close()
# Out:
# [6. 7. 8.]

# %%
#Example2

x = tf.placeholder("float", None)
y = x * 2

writer = tf.summary.FileWriter('./graphs', tf.get_default_graph())
with tf.Session() as session:
    result = session.run(y, feed_dict={x: [1, 2, 3]})
    print(result)
session.close()
writer.close()
# Out:
# [2. 4. 6.]

# %%
#eg 3 with multiple dimensions
x = tf.placeholder("float", [None, 3])
y = x * 2

with tf.Session() as session:
    x_data = [[1, 2, 3],
              [4, 5, 6],]
    result = session.run(y, feed_dict={x: x_data})
    print(result)
# Out:
# [[ 2.  4.  6.]
#  [ 8. 10. 12.]]

# %%
#tf.slice
t = tf.constant([[[1, 1, 1], [2, 2, 2]],
                 [[3, 3, 3], [4, 4, 4]],
                 [[5, 5, 5], [6, 6, 6]]])
n=tf.slice(t,[1,0,0],[2,2,3])
with tf.Session() as s:
    r=s.run(n)
    print(r)
s.close()
# Out:
# [[[3 3 3]
#   [4 4 4]]
#
#  [[5 5 5]
#   [6 6 6]]]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os

# First, load the image again
#dir_path = os.path.dirname(os.path.realpath(__file__))
filename = "./data/img1.jpg"
raw_image_data = mpimg.imread(filename)

image = tf.placeholder("uint8", [None, None, 3])
slice = tf.slice(image, [500, 0, 0], [309, -1, -1])

with tf.Session() as session:
    result = session.run(slice, feed_dict={image: raw_image_data})
    print(result.shape)

plt.imshow(result)
plt.show()
# Out:
# (309, 766, 3)

# %%
plt.imshow(raw_image_data)
plt.show()
